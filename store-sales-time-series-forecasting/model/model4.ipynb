# %% [markdown]
# # Loading

# %%
# Computational imports
import numpy as np   # Library for n-dimensional arrays
import pandas as pd  # Library for dataframes (structured data)

# Helper imports
import os 
import warnings
# import pandas_datareader as web
import datetime as dt

# ML/DL imports
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
from tensorflow.keras.layers import LSTM, Dense, Dropout, RepeatVector, TimeDistributed,GRU,Embedding
from sklearn.preprocessing import MinMaxScaler, OrdinalEncoder
from sklearn.metrics import mean_squared_error, mean_squared_log_error
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# Plotting imports
import matplotlib.pyplot as plt
import matplotlib.dates as dates
# import plotly.express as px
# import plotly.graph_objects as go
# import plotly.figure_factory as ff
# from plotly.subplots import make_subplots
# from plotly.offline import init_notebook_mode, iplot

# Set seeds to make the experiment more reproducible.
from numpy.random import seed
import json
seed(1)

# %%
filepath='model4/'

# %%
train_data = pd.read_csv('train.csv', index_col=0)
test_data = pd.read_csv('test.csv', index_col=0)
data_oil = pd.read_csv('oil.csv')
samp_subm = pd.read_csv('sample_submission.csv')
data_holi = pd.read_csv('holidays_events.csv')
data_store =  pd.read_csv('stores.csv')
data_trans = pd.read_csv('transactions.csv')
# Out:
# C:\Users\User\AppData\Roaming\Python\Python37\site-packages\numpy\lib\arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
all_data = pd.concat([train_data,test_data],ignore_index=True)
all_data['date'] =  pd.to_datetime(all_data['date'])

# %%
df_train1 = all_data.merge(data_holi, on = 'date', how='left')
df_train1 = df_train1.merge(data_oil, on = 'date', how='left')
df_train1 = df_train1.merge(data_store, on = 'store_nbr', how='left')
df_train1 = df_train1.rename(columns = {"type_x" : "holiday_type", "type_y" : "store_type"})
df_train1['day_of_week'] = df_train1['date'].dt.day_name()

# %%
# df['year'] = df['date'].dt.year
# df['month'] = df['date'].dt.month
# df['week'] = df['date'].dt.isocalendar().week
# df['quarter'] = df['date'].dt.quarter


train_columns = ['date','family','sales','day_of_week']
df = df_train1[train_columns]

# %%
num_test,num_train = len(test_data),len(train_data)

# %%
df_copy = df.copy()

# %% [markdown]
# # EDA
# df = train + test

# %% [markdown]
# ### 圖示化

# %%
# buf = df[['date','store_nbr','sales','family']].groupby(['store_nbr','family','date'],as_index = False).agg({"sales":"mean"})
# store = []
# for i in range(1,55):
#     f = list(buf[buf['store_nbr']==i].drop(columns = ['store_nbr']).groupby(['family']))
#     store1 = f[0][1].drop(columns=['family'])
#     for i in range(1,33):
#         store1 = store1.merge(f[i][1].drop(columns=['family']), on = 'date', how='left')
#         store1 = store1.rename(columns = {"sales_x": "sales" ,"sales_y" : f[i][0]})
#     store1 = store1.rename(columns = {"sales": f[0][0]})  
#     store.append(store1)

# %% [markdown]
# ### Transform

# %%
df =df_copy.copy()

# %%
# df.info()

# %%
# df.isnull().sum()

# %%
df['day_of_week'].replace({'Monday':1,'Tuesday':2,'Wednesday':3,'Thursday':4,'Friday':5,'Saturday':6,'Sunday':7},inplace=True)
df['day_of_week'] = df['day_of_week'].astype(int)

# %%
object_cols = [cname for cname in df.columns if df[cname].dtype == "object"]
number_cols = [cname for cname in df.columns if df[cname].dtype!="object" and cname!='date' and cname!='sales']
# buf[col] = ordinal_encoder.fit_transform(buf[col])
print(object_cols,number_cols)
# Out:
# ['family'] ['day_of_week']

# %%
ordinal_encoder = OrdinalEncoder()
df[object_cols] = ordinal_encoder.fit_transform(df[object_cols])

# %% [markdown]
# ### Seperate By family

# %%
# train_x_all = df[:num_train].copy()
train_x_all = df.copy()
train_x_all = list(train_x_all.groupby(["family"]))

# %%
group = [31,30,27,26,23,19,18,16,15,10,6,1]
A_train_x_all = [ train_x_all[i] for i in group]

# %%
condition ={
    'family':'mean',
    'day_of_week':'mean'#!
    }
train_condition = condition.copy()
train_condition['sales'] ='max'

# %%
history_input = 30
train_f_map=list()
for i in range(len(train_x_all)):
    scaler = MinMaxScaler(feature_range=(0,1))
    family_num,train_x = train_x_all[i][0],train_x_all[i][1]
    train_x = train_x.groupby(['date'],as_index=False).agg(train_condition)#ok
    # if i==0:print(train_x)
    for col in number_cols+object_cols:
        train_x[col] = scaler.fit_transform(train_x[col].values.reshape(-1,1))
    train_x = train_x[:589]
    train_y = train_x[['date','sales']]
    train_x.drop(columns=['date','sales','family'],inplace=True)#,'store_nbr','family','onpromotion','locale','store_type','cluster'
    train_y.drop(columns=['date'],inplace=True)

    
    train_input = []
    train_output = []
    for i in range(len(train_x)-history_input+1):
        train_input.append(train_x[i:i+history_input].values)
        train_output.append(train_y.iloc[i+history_input-1])
    train_input=np.array(train_input)
    train_output=np.array(train_output)

    train_f_map.append([train_input,train_output])#,scaler])
    # break

# %%
print(train_f_map[0][0].shape)
print(train_f_map[0][1].shape)
# Out:
# (560, 30, 1)
# (560, 1)

# %%
# def Make_Model_GRU():

# %%
def Multi_Step_LSTM_model():
    
    # Use Keras sequential model
    model = Sequential()    
    
    # First LSTM layer with Dropout regularisation; Set return_sequences to True to feed outputs to next layer
    model.add(LSTM(units = 50, activation='relu', kernel_initializer='he_uniform', return_sequences = True, input_shape = train_input[0].shape )) 
    model.add(Dropout(0.2))
    
    # Second LSTM layer with Dropout regularisation; Set return_sequences to True to feed outputs to next layer
    model.add(LSTM(units = 50,  activation='relu', kernel_initializer='he_uniform', return_sequences = True))                                    
    model.add(Dropout(0.2))
    
    # Final LSTM layer with Dropout regularisation; Set return_sequences to False since now we will be predicting with the output layer
    model.add(LSTM(units = 50))
    model.add(Dropout(0.2))
    
    # The output layer with linear activation to predict Open stock price
    model.add(Dense(units=1, activation = "linear"))
    
    return model

# %%
for i in range(len(train_f_map)):
    print(f"Model {i} training")
    train_input = train_f_map[i][0]
    train_output = train_f_map[i][1]

    model = Multi_Step_LSTM_model()
    model.compile(optimizer='adam', loss='mean_squared_error')#, metrics = ['accuracy'])
    # early_stop = EarlyStopping(monitor='val_loss',patience=2,verbose=1)
    history = model.fit(train_input,train_output, validation_split=0.3,batch_size=4, epochs=2)#,callbacks=early_stop)
    train_f_map[i].append(model)
    train_f_map[i].append(history)
    # break
# Out:
# Model 0 training
# Epoch 1/2
# 98/98 [==============================] - 3s 16ms/step - loss: 713.4455 - val_loss: 342.1882
# Epoch 2/2
# 98/98 [==============================] - 1s 12ms/step - loss: 341.4154 - val_loss: 233.6012
# Model 1 training
# Epoch 1/2
# 98/98 [==============================] - 3s 16ms/step - loss: 0.0934 - val_loss: 2.9337
# Epoch 2/2
# 98/98 [==============================] - 1s 12ms/step - loss: 0.0099 - val_loss: 3.0094
# Model 2 training
# Epoch 1/2
# 98/98 [==============================] - 3s 16ms/step - loss: 81.0401 - val_loss: 32.6105
# Epoch 2/2
# 98/98 [==============================] - 1s 12ms/step - loss: 34.6255 - val_loss: 26.2012
# Model 3 training
# Epoch 1/2
# 98/98 [==============================] - 4s 17ms/step - loss: 24527099.8384 - val_loss: 52987324.0000
# Epoch 2/2
# 98/98 [==============================] - 1s 12ms/step - loss: 24931624.3030 - val_loss: 52917840.0000
# Model 4 training
# Epoch 1/2
# 98/98 [==============================] - 4s 19ms/step - loss: 0.0823 - val_loss: 1.3965e-04
# Epoch 2/2
# 98/98 [==============================] - 1s 14ms/step - loss: 0.0058 - val_loss: 2.0813e-04
# Model 5 training
# Epoch 1/2
# 98/98 [==============================] - 4s 22ms/step - loss: 1338511.3542 - val_loss: 1531379.5000
# Epoch 2/2
# 98/98 [==============================] - 2s 18ms/step - loss: 1250939.6067 - val_loss: 1518450.8750
# Model 6 training
# Epoch 1/2
# 98/98 [==============================] - 4s 23ms/step - loss: 432.1739 - val_loss: 1415.2986
# Epoch 2/2
# 98/98 [==============================] - 2s 18ms/step - loss: 425.8550 - val_loss: 1494.8822
# Model 7 training
# Epoch 1/2
# 98/98 [==============================] - 4s 24ms/step - loss: 6833772.5707 - val_loss: 7403014.0000
# Epoch 2/2
# 98/98 [==============================] - 2s 17ms/step - loss: 6974897.9343 - val_loss: 7376422.0000
# Model 8 training
# Epoch 1/2
# 98/98 [==============================] - 4s 20ms/step - loss: 4170085.8813 - val_loss: 7141636.5000
# Epoch 2/2
# 98/98 [==============================] - 2s 17ms/step - loss: 4192120.0960 - val_loss: 7114683.5000
# Model 9 training
# Epoch 1/2
# 98/98 [==============================] - 4s 20ms/step - loss: 580310.9429 - val_loss: 701722.3125
# Epoch 2/2
# 98/98 [==============================] - 1s 14ms/step - loss: 558206.0275 - val_loss: 692684.8750
# Model 10 training
# Epoch 1/2
# 98/98 [==============================] - 3s 19ms/step - loss: 441556.4309 - val_loss: 495743.8125
# Epoch 2/2
# 98/98 [==============================] - 1s 14ms/step - loss: 414968.4135 - val_loss: 488655.3750
# Model 11 training
# Epoch 1/2
# 98/98 [==============================] - 4s 20ms/step - loss: 1569755.4033 - val_loss: 284715.5000
# Epoch 2/2
# 98/98 [==============================] - 1s 14ms/step - loss: 1926229.6102 - val_loss: 281162.4375
# Model 12 training
# Epoch 1/2
# 98/98 [==============================] - 4s 22ms/step - loss: 108474685.7374 - val_loss: 93124760.0000
# Epoch 2/2
# 98/98 [==============================] - 2s 17ms/step - loss: 92218686.4646 - val_loss: 93019792.0000
# Model 13 training
# Epoch 1/2
# 98/98 [==============================] - 4s 21ms/step - loss: 19225.8034 - val_loss: 8404.1113
# Epoch 2/2
# 98/98 [==============================] - 1s 14ms/step - loss: 41024.1012 - val_loss: 7745.1006
# Model 14 training
# Epoch 1/2
# 98/98 [==============================] - 3s 18ms/step - loss: 19.4373 - val_loss: 4.7286
# Epoch 2/2
# 98/98 [==============================] - 1s 14ms/step - loss: 5.8537 - val_loss: 5.2169
# Model 15 training
# Epoch 1/2
# 98/98 [==============================] - 3s 18ms/step - loss: 2854.4728 - val_loss: 18822.9844
# Epoch 2/2
# 98/98 [==============================] - 1s 14ms/step - loss: 5308.6706 - val_loss: 18501.5977
# Model 16 training
# Epoch 1/2
# 98/98 [==============================] - 4s 21ms/step - loss: 128.1809 - val_loss: 624.5653
# Epoch 2/2
# 98/98 [==============================] - 2s 17ms/step - loss: 134.7674 - val_loss: 603.8992
# Model 17 training
# Epoch 1/2
# 98/98 [==============================] - 4s 23ms/step - loss: 5.7174 - val_loss: 2.3439
# Epoch 2/2
# 98/98 [==============================] - 2s 16ms/step - loss: 3.1699 - val_loss: 2.8946
# Model 18 training
# Epoch 1/2
# 98/98 [==============================] - 4s 19ms/step - loss: 45325.2439 - val_loss: 257637.5469
# Epoch 2/2
# 98/98 [==============================] - 1s 15ms/step - loss: 56037.7467 - val_loss: 255719.8594
# Model 19 training
# Epoch 1/2
# 98/98 [==============================] - 4s 18ms/step - loss: 236.3386 - val_loss: 1544.7935
# Epoch 2/2
# 98/98 [==============================] - 1s 13ms/step - loss: 354.0026 - val_loss: 1586.0638
# Model 20 training
# Epoch 1/2
# 98/98 [==============================] - 3s 18ms/step - loss: 255.0544 - val_loss: 257.6620
# Epoch 2/2
# 98/98 [==============================] - 1s 13ms/step - loss: 94.0420 - val_loss: 159.4653
# Model 21 training
# Epoch 1/2
# 98/98 [==============================] - 3s 17ms/step - loss: 1598.6400 - val_loss: 1221.7633
# Epoch 2/2
# 98/98 [==============================] - 1s 13ms/step - loss: 1408.7253 - val_loss: 995.6527
# Model 22 training
# Epoch 1/2
# 98/98 [==============================] - 3s 17ms/step - loss: 188769.8436 - val_loss: 205941.1250
# Epoch 2/2
# 98/98 [==============================] - 1s 13ms/step - loss: 240499.9678 - val_loss: 203074.2656
# Model 23 training
# Epoch 1/2
# 98/98 [==============================] - 3s 18ms/step - loss: 8.5721 - val_loss: 33.7007
# Epoch 2/2
# 98/98 [==============================] - 1s 13ms/step - loss: 6.8747 - val_loss: 35.9191
# Model 24 training
# Epoch 1/2
# 98/98 [==============================] - 3s 17ms/step - loss: 2502474.9508 - val_loss: 1945816.3750
# Epoch 2/2
# 98/98 [==============================] - 1s 13ms/step - loss: 2498550.0593 - val_loss: 1930915.7500
# Model 25 training
# Epoch 1/2
# 98/98 [==============================] - 4s 22ms/step - loss: 526318.1758 - val_loss: 775623.8750
# Epoch 2/2
# 98/98 [==============================] - 2s 16ms/step - loss: 554968.2317 - val_loss: 766528.6875
# Model 26 training
# Epoch 1/2
# 98/98 [==============================] - 4s 20ms/step - loss: 60.1519 - val_loss: 347.7025
# Epoch 2/2
# 98/98 [==============================] - 2s 15ms/step - loss: 34.1554 - val_loss: 354.9188
# Model 27 training
# Epoch 1/2
# 98/98 [==============================] - 4s 19ms/step - loss: 213.4592 - val_loss: 638.4039
# Epoch 2/2
# 98/98 [==============================] - 1s 15ms/step - loss: 222.8788 - val_loss: 645.3400
# Model 28 training
# Epoch 1/2
# 98/98 [==============================] - 4s 23ms/step - loss: 1414233.6010 - val_loss: 2454334.5000
# Epoch 2/2
# 98/98 [==============================] - 2s 19ms/step - loss: 1315564.4684 - val_loss: 2438342.2500
# Model 29 training
# Epoch 1/2
# 98/98 [==============================] - 3s 18ms/step - loss: 238122.2819 - val_loss: 255903.4062
# Epoch 2/2
# 98/98 [==============================] - 1s 13ms/step - loss: 228486.0533 - val_loss: 250717.0469
# Model 30 training
# Epoch 1/2
# 98/98 [==============================] - 3s 18ms/step - loss: 10352626.8586 - val_loss: 43067464.0000
# Epoch 2/2
# 98/98 [==============================] - 1s 13ms/step - loss: 7527637.9343 - val_loss: 43040120.0000
# Model 31 training
# Epoch 1/2
# 98/98 [==============================] - 3s 18ms/step - loss: 13.2668 - val_loss: 75.0739
# Epoch 2/2
# 98/98 [==============================] - 1s 13ms/step - loss: 10.5187 - val_loss: 72.1176
# Model 32 training
# Epoch 1/2
# 98/98 [==============================] - 3s 18ms/step - loss: 16318.2594 - val_loss: 15673.2500
# Epoch 2/2
# 98/98 [==============================] - 1s 13ms/step - loss: 14606.4873 - val_loss: 14552.1699

# %%
def draw(history,num):
    # val_acc = np.mean(history.history['val_accuracy'])
    # print("\n%s: %.2f%%" % ('val_acc', val_acc*100))
    # plt.plot(history.history['accuracy'])
    # plt.plot(history.history['val_accuracy'])
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model accuracy '+str(num))
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    # plt.legend(['train_acc', 'validation_acc','train_loss','val_loss'], loc='upper left')
    plt.legend(['train_loss','val_loss'], loc='upper left')

    # plt.legend(['train','loss'], loc='upper left')
    plt.show()
for i in range(len(train_f_map)):
    model = train_f_map[i][2]
    history = train_f_map[i][3]

    draw(history,i)
    # serialize model to JSON
    model_json = model.to_json()
    with open(filepath+"model_f"+str(i)+".json", "w") as json_file:
        json_file.write(model_json)
    # serialize weights to HDF5
    model.save_weights(filepath+"model_f"+str(i)+".json.h5")
    print("model_f"+str(i)+"Saved model to disk")
    # break
# Out:
# model_f0Saved model to disk
# model_f1Saved model to disk
# model_f2Saved model to disk
# model_f3Saved model to disk
# model_f4Saved model to disk
# model_f5Saved model to disk
# model_f6Saved model to disk
# model_f7Saved model to disk
# model_f8Saved model to disk
# model_f9Saved model to disk
# model_f10Saved model to disk
# model_f11Saved model to disk
# model_f12Saved model to disk
# model_f13Saved model to disk
# model_f14Saved model to disk
# model_f15Saved model to disk
# model_f16Saved model to disk
# model_f17Saved model to disk
# model_f18Saved model to disk
# model_f19Saved model to disk
# model_f20Saved model to disk
# model_f21Saved model to disk
# model_f22Saved model to disk
# model_f23Saved model to disk
# model_f24Saved model to disk
# model_f25Saved model to disk
# model_f26Saved model to disk
# model_f27Saved model to disk
# model_f28Saved model to disk
# model_f29Saved model to disk
# model_f30Saved model to disk
# model_f31Saved model to disk
# model_f32Saved model to disk

# %% [markdown]
# # Perdict

# %%
test_x_all =  df[num_train:].copy().drop(columns=['sales'])
test_x_all = list(test_x_all.groupby(["family"],as_index=False))

train_x_all_buf =  df[:num_train].copy().drop(columns=['sales'])
train_x_all_buf = list(train_x_all_buf.groupby(["family"],as_index=False))

# %%
test_f_map=list()
for i in range(len(test_x_all)):
    test_x = test_x_all[i][1]
    test_x = test_x.groupby(['date'],as_index=False).agg(condition)

    family_num,train_x_buf = train_x_all_buf[i][0],train_x_all_buf[i][1]
    train_x_buf = train_x_buf.groupby(['date'],as_index=False).agg(condition)#ok
    # for col in number_cols+object_cols:
    #     if col=='sales':continue
    #     train_x_buf[col] = scaler.fit_transform(train_x_buf[col].values.reshape(-1,1))

    test_x = pd.concat([train_x_buf[-1*(history_input)+1:],test_x],ignore_index=True)
    test_f_map.append([test_x])

# %%
test_output = []
test_ = df[num_train:].copy()
for i in range(len(test_['date'])):
    test_input = []
    f_num = int(test_['family'].iloc[0])
    # print(f_num)
    test_x = test_f_map[f_num][0]

    end = test_x.index[test_x['date']==test_['date'].iloc[i]].tolist()[0]
    start = end - history_input + 1
    test_input.append(pd.concat([test_x[start:end],test_[i:i+1]]).drop(columns=['date','sales','family']).values)
    test_input=np.array(test_input)

    model = train_f_map[f_num][2]
    y_pred = model.predict(test_input)
    test_output.append(y_pred[0].tolist()[0])

    if i%100==0:
        print("Count ",i/100," *100 data.")
# Out:
# Count  0.0  *100 data.
# Count  1.0  *100 data.
# Count  2.0  *100 data.
# Count  3.0  *100 data.
# Count  4.0  *100 data.
# Count  5.0  *100 data.
# Count  6.0  *100 data.
# Count  7.0  *100 data.
# Count  8.0  *100 data.
# Count  9.0  *100 data.
# Count  10.0  *100 data.
# Count  11.0  *100 data.
# Count  12.0  *100 data.
# Count  13.0  *100 data.
# Count  14.0  *100 data.
# Count  15.0  *100 data.
# Count  16.0  *100 data.
# Count  17.0  *100 data.
# Count  18.0  *100 data.
# Count  19.0  *100 data.
# Count  20.0  *100 data.
# Count  21.0  *100 data.
# Count  22.0  *100 data.
# Count  23.0  *100 data.
# Count  24.0  *100 data.
# Count  25.0  *100 data.
# Count  26.0  *100 data.
# Count  27.0  *100 data.
# Count  28.0  *100 data.
# Count  29.0  *100 data.
# Count  30.0  *100 data.
# Count  31.0  *100 data.
# Count  32.0  *100 data.
# Count  33.0  *100 data.
# Count  34.0  *100 data.
# Count  35.0  *100 data.
# Count  36.0  *100 data.
# Count  37.0  *100 data.
# Count  38.0  *100 data.
# Count  39.0  *100 data.
# Count  40.0  *100 data.
# Count  41.0  *100 data.
# Count  42.0  *100 data.
# Count  43.0  *100 data.
# Count  44.0  *100 data.
# Count  45.0  *100 data.
# Count  46.0  *100 data.
# Count  47.0  *100 data.
# Count  48.0  *100 data.
# Count  49.0  *100 data.
# Count  50.0  *100 data.
# Count  51.0  *100 data.
# Count  52.0  *100 data.
# Count  53.0  *100 data.
# Count  54.0  *100 data.
# Count  55.0  *100 data.
# Count  56.0  *100 data.
# Count  57.0  *100 data.
# Count  58.0  *100 data.
# Count  59.0  *100 data.
# Count  60.0  *100 data.
# Count  61.0  *100 data.
# Count  62.0  *100 data.
# Count  63.0  *100 data.
# Count  64.0  *100 data.
# Count  65.0  *100 data.
# Count  66.0  *100 data.
# Count  67.0  *100 data.
# Count  68.0  *100 data.
# Count  69.0  *100 data.
# Count  70.0  *100 data.
# Count  71.0  *100 data.
# Count  72.0  *100 data.
# Count  73.0  *100 data.
# Count  74.0  *100 data.
# Count  75.0  *100 data.
# Count  76.0  *100 data.
# Count  77.0  *100 data.
# Count  78.0  *100 data.
# Count  79.0  *100 data.
# Count  80.0  *100 data.
# Count  81.0  *100 data.
# Count  82.0  *100 data.
# Count  83.0  *100 data.
# Count  84.0  *100 data.
# Count  85.0  *100 data.
# Count  86.0  *100 data.
# Count  87.0  *100 data.
# Count  88.0  *100 data.
# Count  89.0  *100 data.
# Count  90.0  *100 data.
# Count  91.0  *100 data.
# Count  92.0  *100 data.
# Count  93.0  *100 data.
# Count  94.0  *100 data.
# Count  95.0  *100 data.
# Count  96.0  *100 data.
# Count  97.0  *100 data.
# Count  98.0  *100 data.
# Count  99.0  *100 data.
# Count  100.0  *100 data.
# Count  101.0  *100 data.
# Count  102.0  *100 data.
# Count  103.0  *100 data.
# Count  104.0  *100 data.
# Count  105.0  *100 data.
# Count  106.0  *100 data.
# Count  107.0  *100 data.
# Count  108.0  *100 data.
# Count  109.0  *100 data.
# Count  110.0  *100 data.
# Count  111.0  *100 data.
# Count  112.0  *100 data.
# Count  113.0  *100 data.
# Count  114.0  *100 data.
# Count  115.0  *100 data.
# Count  116.0  *100 data.
# Count  117.0  *100 data.
# Count  118.0  *100 data.
# Count  119.0  *100 data.
# Count  120.0  *100 data.
# Count  121.0  *100 data.
# Count  122.0  *100 data.
# Count  123.0  *100 data.
# Count  124.0  *100 data.
# Count  125.0  *100 data.
# Count  126.0  *100 data.
# Count  127.0  *100 data.
# Count  128.0  *100 data.
# Count  129.0  *100 data.
# Count  130.0  *100 data.
# Count  131.0  *100 data.
# Count  132.0  *100 data.
# Count  133.0  *100 data.
# Count  134.0  *100 data.
# Count  135.0  *100 data.
# Count  136.0  *100 data.
# Count  137.0  *100 data.
# Count  138.0  *100 data.
# Count  139.0  *100 data.
# Count  140.0  *100 data.
# Count  141.0  *100 data.
# Count  142.0  *100 data.
# Count  143.0  *100 data.
# Count  144.0  *100 data.
# Count  145.0  *100 data.
# Count  146.0  *100 data.
# Count  147.0  *100 data.
# Count  148.0  *100 data.
# Count  149.0  *100 data.
# Count  150.0  *100 data.
# Count  151.0  *100 data.
# Count  152.0  *100 data.
# Count  153.0  *100 data.
# Count  154.0  *100 data.
# Count  155.0  *100 data.
# Count  156.0  *100 data.
# Count  157.0  *100 data.
# Count  158.0  *100 data.
# Count  159.0  *100 data.
# Count  160.0  *100 data.
# Count  161.0  *100 data.
# Count  162.0  *100 data.
# Count  163.0  *100 data.
# Count  164.0  *100 data.
# Count  165.0  *100 data.
# Count  166.0  *100 data.
# Count  167.0  *100 data.
# Count  168.0  *100 data.
# Count  169.0  *100 data.
# Count  170.0  *100 data.
# Count  171.0  *100 data.
# Count  172.0  *100 data.
# Count  173.0  *100 data.
# Count  174.0  *100 data.
# Count  175.0  *100 data.
# Count  176.0  *100 data.
# Count  177.0  *100 data.
# Count  178.0  *100 data.
# Count  179.0  *100 data.
# Count  180.0  *100 data.
# Count  181.0  *100 data.
# Count  182.0  *100 data.
# Count  183.0  *100 data.
# Count  184.0  *100 data.
# Count  185.0  *100 data.
# Count  186.0  *100 data.
# Count  187.0  *100 data.
# Count  188.0  *100 data.
# Count  189.0  *100 data.
# Count  190.0  *100 data.
# Count  191.0  *100 data.
# Count  192.0  *100 data.
# Count  193.0  *100 data.
# Count  194.0  *100 data.
# Count  195.0  *100 data.
# Count  196.0  *100 data.
# Count  197.0  *100 data.
# Count  198.0  *100 data.
# Count  199.0  *100 data.
# Count  200.0  *100 data.
# Count  201.0  *100 data.
# Count  202.0  *100 data.
# Count  203.0  *100 data.
# Count  204.0  *100 data.
# Count  205.0  *100 data.
# Count  206.0  *100 data.
# Count  207.0  *100 data.
# Count  208.0  *100 data.
# Count  209.0  *100 data.
# Count  210.0  *100 data.
# Count  211.0  *100 data.
# Count  212.0  *100 data.
# Count  213.0  *100 data.
# Count  214.0  *100 data.
# Count  215.0  *100 data.
# Count  216.0  *100 data.
# Count  217.0  *100 data.
# Count  218.0  *100 data.
# Count  219.0  *100 data.
# Count  220.0  *100 data.
# Count  221.0  *100 data.
# Count  222.0  *100 data.
# Count  223.0  *100 data.
# Count  224.0  *100 data.
# Count  225.0  *100 data.
# Count  226.0  *100 data.
# Count  227.0  *100 data.
# Count  228.0  *100 data.
# Count  229.0  *100 data.
# Count  230.0  *100 data.
# Count  231.0  *100 data.
# Count  232.0  *100 data.
# Count  233.0  *100 data.
# Count  234.0  *100 data.
# Count  235.0  *100 data.
# Count  236.0  *100 data.
# Count  237.0  *100 data.
# Count  238.0  *100 data.
# Count  239.0  *100 data.
# Count  240.0  *100 data.
# Count  241.0  *100 data.
# Count  242.0  *100 data.
# Count  243.0  *100 data.
# Count  244.0  *100 data.
# Count  245.0  *100 data.
# Count  246.0  *100 data.
# Count  247.0  *100 data.
# Count  248.0  *100 data.
# Count  249.0  *100 data.
# Count  250.0  *100 data.
# Count  251.0  *100 data.
# Count  252.0  *100 data.
# Count  253.0  *100 data.
# Count  254.0  *100 data.
# Count  255.0  *100 data.
# Count  256.0  *100 data.
# Count  257.0  *100 data.
# Count  258.0  *100 data.
# Count  259.0  *100 data.
# Count  260.0  *100 data.
# Count  261.0  *100 data.
# Count  262.0  *100 data.
# Count  263.0  *100 data.
# Count  264.0  *100 data.
# Count  265.0  *100 data.
# Count  266.0  *100 data.
# Count  267.0  *100 data.
# Count  268.0  *100 data.
# Count  269.0  *100 data.
# Count  270.0  *100 data.
# Count  271.0  *100 data.
# Count  272.0  *100 data.
# Count  273.0  *100 data.
# Count  274.0  *100 data.
# Count  275.0  *100 data.
# Count  276.0  *100 data.
# Count  277.0  *100 data.
# Count  278.0  *100 data.
# Count  279.0  *100 data.
# Count  280.0  *100 data.
# Count  281.0  *100 data.
# Count  282.0  *100 data.
# Count  283.0  *100 data.
# Count  284.0  *100 data.
# Count  285.0  *100 data.

# %%
print(test_output)
# Out:
# [11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, 11.603784561157227, ...

# %%
test_data = pd.read_csv('test.csv')
submit = test_data[['id']]
submit['sales'] = test_output

# %%
submit.to_csv(filepath+"submit.csv",index=False,sep=',')
import zipfile
with zipfile.ZipFile(filepath+'submit.zip', 'w') as zf:
    zf.write(filepath+'submit.csv')
